# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import mne
from mne.io import read_raw_edf
import os
import re
import scipy
from scipy.signal import welch
from scipy.integrate import simps
from time import time
import pickle
import matplotlib.cm as cm

# %%
# Reference: https://raphaelvallat.com/bandpower.html
# Reference: https://stackoverflow.com/questions/44547669/python-numpy-equivalent-of-bandpower-from-matlab
def bandpower(seq, sampling_frequency, frequency_band):
    f, Pxx = scipy.signal.periodogram(seq, fs=sampling_frequency)
    ind_min = scipy.argmax(f > frequency_band[0]) - 1
    ind_max = scipy.argmax(f > frequency_band[1]) - 1
    return scipy.trapz(Pxx[ind_min: ind_max], f[ind_min: ind_max])

# %%
BASE_PATH = '../data'
eeg_info_df = pd.read_csv(f'{BASE_PATH}/eeg_info_df.csv')

frequency_bands = {'Beta': [12, 30],
                   'Alpha': [8, 12],
                   'Theta': [4, 8],
                   'Delta': [0.5, 4]}
band_names = list(frequency_bands.keys())
shared_channels = ['EEG Fpz-Cz', 'EEG Pz-Oz', 'EOG horizontal', 'EMG submental']

feature_list = []
label_list = []
path_list = []
sf = 100

time_interval = 3600

tic = time()
for i, path in enumerate(eeg_info_df.path.values):
    raw_edf = read_raw_edf(os.path.join(BASE_PATH, eeg_info_df.path.iloc[i]))
    edf_df = raw_edf.to_data_frame()
    edf_df = edf_df[edf_df['EEG Fpz-Cz'] > -1000] # remove outliers

    n = edf_df.shape[0]
    n_hours = n//(time_interval*100)
    for j in range(n_hours):
        temp_df = edf_df.iloc[(j*time_interval*100):((j+1)*time_interval*100), :]
        features = [bandpower(temp_df[channel].values, sf, frequency_bands[band])
                    for channel in shared_channels for band in band_names]
        feature_list.append(features)
        label_list.append(1 if path.find('telemetry') > -1 else 0)
        path_list.append(path)
    if i == 0 : print('1st eeg takes {} seconds\n'.format(round(time()-tic)))

toc = time()
print('one hour band power calculation for 4 bands x 4 channels takes {} seconds'.format(round(toc-tic)))
# one hour band power calculation for 4 bands x 4 channels takes 897 seconds

y = np.array(label_list)
X = np.array(feature_list)
paths = np.array(path_list)

pickle.dump((X, y, paths), open(f'{BASE_PATH}/model_data_v1.sav', 'wb'))
# Out:
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# 1st eeg takes 12 seconds
#
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4002E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4011E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4012E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4021E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4022E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4031E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4032E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4041E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4042E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4051E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4052E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4061E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4062E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4071E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4072E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4081E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4082E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4091E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4092E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4101E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4102E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4111E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4112E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4121E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4122E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4131E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4141E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4142E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4151E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4152E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4161E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4162E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4171E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4172E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4181E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4182E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4191E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4192E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4201E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4202E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4211E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4212E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4221E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4222E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4231E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4232E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4241E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4242E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4251E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4252E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4261F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4262F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4271F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4272F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4281G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4282G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4291G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4292G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4301E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4302E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4311E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4312E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4321E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4322E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4331F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4332F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4341F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4342F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4351F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4352F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4362F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4371F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4372F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4381F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4382F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4401E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4402E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4411E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4412E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4421E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4422E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4431E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4432E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4441E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4442E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4451F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4452F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4461F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4462F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4471F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4472F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4481F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4482F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4491G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4492G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4501E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4502E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4511E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4512E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4522E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4531E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4532E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4541F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4542F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4551F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4552F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4561F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4562F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4571F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4572F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4581G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4582G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4591G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4592G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4601E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4602E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4611E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4612E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4621E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4622E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4631E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4632E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4641E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4642E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4651E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4652E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4661E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4662E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4671G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4672G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4701E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4702E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4711E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4712E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4721E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4722E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4731E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4732E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4741E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4742E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4751E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4752E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4761E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4762E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4771G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4772G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4801G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4802G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4811G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4812G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4821G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-cassette/SC4822G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7011J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7012J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7021J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7022J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7041J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7042J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7051J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7052J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7061J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7062J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7071J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7072J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7081J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7082J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7091J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7092J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7101J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7102J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7111J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7112J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7121J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7122J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7131J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7132J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7141J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7142J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7151J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7152J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7161J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7162J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7171J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7172J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7181J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7182J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7191J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7192J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7201J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7202J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7211J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7212J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7221J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7222J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7241J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# Extracting EDF parameters from /Users/oulrich/Projects/MastersDegree/Semesters/2019_Fall/CSE-6250-HealthData/Project/CSE6250-project/data/sleep-telemetry/ST7242J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Converting "time" to "<class 'numpy.int64'>"...
# one hour band power calculation for 4 bands x 4 channels takes 2096 seconds
